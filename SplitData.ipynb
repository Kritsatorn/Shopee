# %%
import shutil
import os

# %%
base_dir = '/Users/kritsatornsaengweang/Downloads/shopee-product-detection-dataset'
train_dir = os.path.join(base_dir, 'train/train')
validation_dir = os.path.join(base_dir, 'train/test')

# %%
for i in range (0,5) :
    for j in range(0,10) :
        if ( i == 4 and j >= 2) :
            break
        path = os.path.join(train_dir, str(i) + str(j))
        destination = os.path.join(validation_dir, str(i) + str(j))
#         print(str(i) + str(j))
        setx =  os.listdir(path)
        for x in setx[:100]:
#             new_path = shutil.move(x, destination)
            os.rename(str(os.path.join(path, str(x))) ,str(os.path.join(destination, str(x))) )
            print(x)
# Out:
# d415f1f957c8f5d541b6067e3ee35141.jpg
# 9519ce5c45863b4df9ccaac21f05d34c.jpg
# 21cb9c6d6b20b064fdbede2f6428e35f.jpg
# dfca61bee5d02624e79ec70e7e33d316.jpg
# 7c0bdae7b1222a4b6c7fdcab8a296b2e.jpg
# 74601a2509486eb324474283f3c4d0fd.jpg
# e4c82bd847b33ed48461060ef119fa20.jpg
# e80ad703afde1f8d10073d42ab9ceec6.jpg
# be2a815381f298af7e51d4979e7c814e.jpg
# 1376609993c5636bdff6c9388f4f44eb.jpg
# 4a31465da094f34ce18d4d8bcd55bdd0.jpg
# dec1020613d09148b6f1cc87abb45dac.jpg
# f25ceab211d35ee2635eb77fdc25a798.jpg
# 9392c039d9faf0aaefd98b63f949cd65.jpg
# 123c30461ebc413bd6a7c067fe5cab0c.jpg
# 1d50944d58de8edaafbb49f3218b8592.jpg
# 2450fcdac64eb34c43c0bb1d71992121.jpg
# a8eb96c2544113bf48b30b85d7487309.jpg
# c78bfd365b4a1d1ea8efa84f3f342545.jpg
# fae721e85a4921f66f824ba9b6ad5264.jpg
# 530cda2d719596ba578e814af134ae0f.jpg
# 792fa0ead4e9e571dee1903732c1e6be.jpg
# 02d9c90e5fefc7dc22f2d56117bffeb9.jpg
# 5a18222633400d22283c08855dc90217.jpg
# ecb04848efcb8a8b2a1819efe7e7c9a1.jpg
# ...
